# %%
import pandas as pd
import numpy as np

# %%
# read the csv "test_demo.csv" can be replace with any other filename you want to input
df = pd.read_csv("test_demo.csv")

# create a new column named "UniqueID" from 1,2,3,4,5,...to n(n is # of rows we have)
# UniqueID is using to link the Source and Associate Twitter Handle, which should create by system
# usually it is used by system only
df.insert(0, "UniqueID", range(1, len(df) + 1), True)

# showing the csv
df
# Out:
#    UniqueID                   Source  RSS feed URLs (where available)  \
# 0         1              @Marianhouk                              NaN
# 1         2  http://calcalist.co.il/                              NaN
# 2         3   https://www.debka.com/                              NaN
# 3         4               @GerAmbTLV                              NaN
#
#              Type                              Tags  \
# 0  Twitter Handle               Twitter Journalists
# 1     News Source          Israeli|Hebrew|Financial
# 2     News Source  Israeli|English|Hawkish|Security
# 3  Twitter Handle               Twitter Journalists
#
#    Associated Twitter Handle Associated Publisher                  Name  \
# 0                        NaN                  NaN           Marian Houk
# 1                 @calcalist               Yediot             Calcalist
# 2  @debkafile|@debka_english           Debka File  Debka File - English
# 3                        NaN                  NaN  Susanne.Wasum-Rainer
#
#            Text aliases
# 0           Marian Houk
# 1             Calcalist
# 2            Debka File
# 3  Susanne.Wasum-Rainer

# %%
#### this is old input file so just ignore it####

# deal with "Other language version" first
# identify rows where "Other language version" is not null
#not_null = df.loc[pd.notna(df["Associated Publisher"]), :].index


# create a new dataframe with the values that We requested,
# based on the index rows found above.
# new_df_to_add = pd.DataFrame({'UniqueID':df.iloc[not_null,0],
#                               'Source': df.iloc[not_null,9],
#                               "RSS feed URLs (where available)":np.nan,
#                               'Type': "News Source",
#                               'Tags': df.iloc[not_null,4],
#                               'Location':df.iloc[not_null,5],
#                               'Associated Twitter Handle': np.nan,
#                               'Name':df.iloc[not_null,7],
#                               'Text aliases': np.nan,
#                               'Associated Publisher': np.nan}) 

# new_df_to_add

# %%
# to find every non-empty Associate Twitter Handle's rows's index and store into not_null_twitter 
# for example if row 0 exist associate twitter handle, then it will be stored in not_null_twitter 
not_null_twitter = df.loc[pd.notna(df["Associated Twitter Handle"]), :].index

# create new rows for every Associate Twitter Handle, in this case source will be the old assciated twitter handle
# Type to be "Twitter Handle", UniqueID, Tags and Name will keep same.
new_df_to_add_twitter = pd.DataFrame({'UniqueID':df.iloc[not_null_twitter,0],
                              'Source': df.iloc[not_null_twitter,5],
                              "RSS feed URLs (where available)":np.nan,
                              'Type': "Twitter Handle",
                              'Tags': df.iloc[not_null_twitter,4],
                              'Associated Twitter Handle': np.nan,
                              'Associated Publisher': np.nan,
                              'Name':df.iloc[not_null_twitter,7],        
                              'Text aliases': np.nan})

# since some of associated twitter Handle will be 2 or 3, so it use "|" to split
# and make every twitter handle as a new record
new_df_to_add_twitter["Source"] = new_df_to_add_twitter["Source"].str.split("|")
new_df_to_add_twitter = new_df_to_add_twitter.explode("Source")
new_df_to_add_twitter
# Out:
#    UniqueID          Source  RSS feed URLs (where available)            Type  \
# 1         2      @calcalist                              NaN  Twitter Handle
# 2         3      @debkafile                              NaN  Twitter Handle
# 2         3  @debka_english                              NaN  Twitter Handle
#
#                                Tags  Associated Twitter Handle  \
# 1          Israeli|Hebrew|Financial                        NaN
# 2  Israeli|English|Hawkish|Security                        NaN
# 2  Israeli|English|Hawkish|Security                        NaN
#
#    Associated Publisher                  Name  Text aliases
# 1                   NaN             Calcalist           NaN
# 2                   NaN  Debka File - English           NaN
# 2                   NaN  Debka File - English           NaN

# %%
# add the new rows into the origin dataframe and sorted by UniqueID
df = df.append(new_df_to_add_twitter)
df = df.sort_values(by=['UniqueID'])
df
# Out:
#    UniqueID                   Source  RSS feed URLs (where available)  \
# 0         1              @Marianhouk                              NaN
# 1         2  http://calcalist.co.il/                              NaN
# 1         2               @calcalist                              NaN
# 2         3   https://www.debka.com/                              NaN
# 2         3               @debkafile                              NaN
# 2         3           @debka_english                              NaN
# 3         4               @GerAmbTLV                              NaN
#
#              Type                              Tags  \
# 0  Twitter Handle               Twitter Journalists
# 1     News Source          Israeli|Hebrew|Financial
# 1  Twitter Handle          Israeli|Hebrew|Financial
# 2     News Source  Israeli|English|Hawkish|Security
# 2  Twitter Handle  Israeli|English|Hawkish|Security
# 2  Twitter Handle  Israeli|English|Hawkish|Security
# 3  Twitter Handle               Twitter Journalists
#
#    Associated Twitter Handle Associated Publisher                  Name  \
# 0                        NaN                  NaN           Marian Houk
# 1                 @calcalist               Yediot             Calcalist
# 1                        NaN                  NaN             Calcalist
# 2  @debkafile|@debka_english           Debka File  Debka File - English
# 2                        NaN                  NaN  Debka File - English
# 2                        NaN                  NaN  Debka File - English
# 3                        NaN                  NaN  Susanne.Wasum-Rainer
#
#            Text aliases
# 0           Marian Houk
# 1             Calcalist
# 1                   NaN
# 2            Debka File
# 2                   NaN
# 2                   NaN
# 3  Susanne.Wasum-Rainer

# %%
l = [x for _,x in df.groupby('Type')]
l[0]
# Out:
#      UniqueID                          Source  \
# 337       338              http://972mag.com/
# 338       339            http://mekomit.co.il
# 339       340  http://israelnationalnews.com/
# 340       341               http://inn.co.il/
# 341       342         http://calcalist.co.il/
# 342       343          https://www.debka.com/
# 343       344             http://debka.co.il/
# 344       345            http://globes.co.il/
# 345       346          http://en.globes.co.il
# 346       347             http://haaretz.com/
# 347       348           http://haaretz.co.il/
# 348       349             http://hamodia.com/
# 349       350         http://israelhayom.com/
# 350       351       http://israelhayom.co.il/
# 351       352           http://www.jdn.co.il/
# 352       353               http://jpost.com/
# 353       354       http://makorrishon.co.il/
# 354       355       https://www.maariv.co.il/
# 355       356           http://themarker.com/
# 356       357       http://timesofisrael.com/
# 357       358               http://zman.co.il
# 358       359            http://ynetnews.com/
#
#          Associated Twitter Handle                     Associated Publisher  \
# 337                        @972mag                                   972Mag
# 338                       @mekomit                                   972Mag
# 339                 @ArutzSheva_En                                  Arutz 7
# 340                     @arutz7heb                                  Arutz 7
# 341                     @calcalist                                   Yediot
# 342      @debkafile|@debka_english                               Debka File
# 343                  @debka_hebrew                               Debka File
# 344                    @globesnews                                   Globes
# 345                 @GlobesEnglish                                   Globes
# 346                    @haaretzcom                                  Haaretz
# 347                       @Haaretz                                  Haaretz
# 348                     @HamodiaUS                                  HaModia
# 349                @IsraelHayomEng                             Israel Hayom
# 350                @IsraelHayomHeb                             Israel Hayom
# 351                       @JDNfeed                                  HaModia
# 352  @Jerusalem_Post|@JPostOpinion                           Jerusalem Post
# 353                   @MakorRishon                             Israel Hayom
# 354                  @maarivonline                           Jerusalem Post
# 355                     @TheMarker                                  Haaretz
# 356                 @TimesofIsrael                          Times of Israel
# 357                    @ZmanIsrael                          Times of Israel
# 358                      @ynetnews                                   Yediot
# 359                    @ynetalerts                                   Yediot
# 360                 @rosnersdomain                            Shmuel Rosner
# 361                     @GPOIsrael          Israeli Government Press Office
# 362                            NaN          Israeli Government Press Office
# 363                      @NoCamels                                 Nocamels
# 364                @MaanNewsAgency                        Ma'an News Agency
# 365                @PalestineChron                      Palestine Chronicle
# 366                    @pnnenglish                   Palestine News Network
# 367               @WAFANewsEnglish  Wafa (Palestinian News and Information)
# 368                       @WAFA_PS  Wafa (Palestinian News and Information)
#
#                                                   Name  \
# 337                                             972mag
# 338                                      Sikha Mekomit
# 339                                  Arutz 7 - English
# 340                                   Arutz 7 - Hebrew
# 341                                          Calcalist
# 342                               Debka File - English
# 343                                Debka File - Hebrew
# 344                                             Globes
# 345                                   Globes - English
# 346                                  Haaretz - English
# 347                                   Haaretz - Hebrew
# 348                                            HaModia
# 349                             Israel Hayom - English
# 350                              Israel Hayom - Hebrew
# 351                        Jewish Ultra-Orthodox News
# 352                                     Jerusalem Post
# 353                                       Makor Rishon
# 354                                             Maariv
# 355                                         The Marker
# 356                                    Times of Israel
# 357                                        Zman Israel
# 358                                     Ynet - English
# 359                                      Ynet - Hebrew
# 360                                      Shmuel Rosner
# 361          Israeli Government Press Office - English
# 362           Israeli Government Press Office - Hebrew
# 363                                          Nocamels
# 364                                  Ma'an News Agency
# 365                                Palestine Chronicle
# 366                             Palestine News Network
# 367  Wafa (Palestinian News and Info Agency) - English
# 368   Wafa (Palestinian News and Info Agency) - Arabic
#
#                               Text aliases
# 337                                 972mag
# 338               sikha mekomit|Local Call
# 339       Arutz 7|Israel National News|INN
# 340       Arutz 7|Israel National News|INN
# 341                              Calcalist
# 342                             Debka File
# 343                             Debka File
# 344                                 Globes
# 345                                Globes
# 346                       Haaretz|Ha'aretz
# 347                       Haaretz|Ha'aretz
# 348                                HaModia
# 349                           Israel Hayom
# 350                           Israel Hayom
# 351     Jewish Ultra-Orthodox News|HaModia
# 352                   Jerusalem Post|Jpost
# 353                           Makor Rishon
# 354                     Maariv|Ma'ariv|NRG
# 355                   The Marker|TheMarker
# 356                        Times of Israel
# 357                 Zman Israel|ZmanIsrael
# 358           Ynet|Yediot|Yedioth|ynetnews
# 359           Ynet|Yediot|Yedioth|ynetnews
# 360                          Shmuel Rosner
# 361        Israeli Government Press Office
# 362        Israeli Government Press Office
# 363                              Nocamels
# 364                Ma'an News Agency|Ma'an
# 365                    Palestine Chronicle
# 366                 Palestine News Network
# 367  Wafa|Palestinian News and Info Agency
# 368  Wafa|Palestinian News and Info Agency

# %%
l[1]
# Out:
#      UniqueID            Source  RSS feed URLs (where available)  \
# 0           1       @Marianhouk                              NaN
# 1           2     @NTarnopolsky                              NaN
# 2           3       @ColinKahl                               NaN
# 3           4   @JGreenblattADL                              NaN
# 4           5         @iramfali                              NaN
# ..        ...               ...                              ...
# 364       365   @MaanNewsAgency                              NaN
# 365       366   @PalestineChron                              NaN
# 366       367       @pnnenglish                              NaN
# 367       368  @WAFANewsEnglish                              NaN
# 368       369          @WAFA_PS                              NaN
#
#                Type                                          Tags  \
# 0    Twitter Handle                           Twitter Journalists
# 1    Twitter Handle                           Twitter Journalists
# 2    Twitter Handle                           Twitter Journalists
# 3    Twitter Handle                           Twitter Journalists
# 4    Twitter Handle                           Twitter Journalists
# ..              ...                                           ...
# 364  Twitter Handle           Palestinian|English|Current-Affairs
# 365  Twitter Handle           Palestinian|English|Current-Affairs
# 366  Twitter Handle           Palestinian|English|Current-Affairs
# 367  Twitter Handle  Palestinian|English|Official|Current-Affairs
# 368  Twitter Handle   Palestinian|Arabic|Official|Current-Affairs
#
#     Associated Twitter Handle Associated Publisher  \
# 0                         NaN                  NaN
# 1                         NaN                  NaN
# 2                         NaN                  NaN
# 3                         NaN                  NaN
# 4                         NaN                  NaN
# ..                        ...                  ...
# 364                       NaN                  NaN
# 365                       NaN                  NaN
# 366                       NaN                  NaN
# 367                       NaN                  NaN
# 368                       NaN                  NaN
#
#                                                   Name         Text aliases
# 0                                          Marian Houk          Marian Houk
# 1                                     Noga Tarnopolsky     Noga Tarnopolsky
# 2                                          Colin Kahl           Colin Kahl
# 3                                  Jonathan Greenblatt  Jonathan Greenblatt
# 4                                            Imram Ali            Imram Ali
# ..                                                 ...                  ...
# 364                                  Ma'an News Agency                  NaN
# 365                                Palestine Chronicle                  NaN
# 366                             Palestine News Network                  NaN
# 367  Wafa (Palestinian News and Info Agency) - English                  NaN
# 368   Wafa (Palestinian News and Info Agency) - Arabic                  NaN
#
# [370 rows x 9 columns]

# %%
l[1].to_csv('twitter.csv', index=False)
l[0].to_csv('domain.csv', index=False)
