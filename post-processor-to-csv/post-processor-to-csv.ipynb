# %%
import ijson
from datetime import date
from shutil import copyfile

# %%
with open("../data/current/output.json", "r") as output:
    parser = ijson.parse(output)
    current = ""
    columns = ""
    column_set = False
    curr_col = ""
    multi_columns = []
    entry_id=""
    # output_dd_mm_yyyy.csv
    today = date.today()
    date_string = today.strftime("%d-%m-%Y")
    output_file_name = 'csvOutput/output_'+date_string+'.csv'
    with open(output_file_name,'w', encoding="utf-8") as file:
        for prefix, event, value in parser:
            # Adds columns
            if event == "map_key":
                if prefix == "":
                    entry_id = value
                else:
                    curr_col = value
                    if not column_set:
                        columns+=curr_col+","
            if prefix == entry_id+"."+curr_col:
                # Parses [, means there will be an array, so an empty string is created
                if event == "start_array":
                    multi_columns.append("")
                # Parses ], means the array is done, so the last element of the list
                # is added to current row
                elif event == "end_array":
                    current+=multi_columns[-1]+","
                else:
                    if not value:
                        current +="null,"
                    elif type(value) == int:
                        current +=str(value)+","
                    else:
                        # Replaces commas to not mess up the csv structure
                        current+=value.replace(",","")+","
            # This means it's an item of a list, so we add it to the last element of the list
            elif prefix == entry_id+"."+curr_col+".item":
                multi_columns[-1]+=value+" "
            # Marks the end of the element
            elif entry_id != "" and prefix == entry_id and event == "end_map":
                if not column_set:
                    file.write(columns+"\n")
                    print("Column "+columns)
                    column_set = True
                file.write(current+"\n")
                print("Sent "+entry_id)
                current = ""
                curr_col = ""
                multi_columns = []
                entry_id = ""
        #print('prefix={}, event={}, value={}'.format(prefix, event, value))

        #copy this csv output to stacked area graph for processing
        copyfile(output_file_name,'../stacked-area-graph/input_for_stacked_area_graph.csv')
    print("DONE! check "+output_file_name)
# Out:
# Column id,url or alias text,referring record id,number of referrals,type,associated publisher,tags,name/title,language,authors,date of publication,plain text,image reference,anchor text,
# Sent e93fd1c0-8664-5863-890a-8eb0caac2760
# Sent 0f8ed509-4c91-5f4b-a4d0-e14ad00e1972
# Sent 9aeb93a6-b1b1-5692-89d6-9e309296d704
# Sent e37933b7-7587-5bce-ba09-1716711e3035
# Sent e5afe261-4de0-503c-86d6-f5e71f49f031
# Sent b615442b-10f4-5a29-9353-274f3c6f5243
# Sent 3661c76b-2f69-5bb2-9d55-b4abe98cfc08
# Sent e7e87778-ba90-5bcd-9de5-c2e1281e9486
# Sent 0634a0d0-4582-552d-8ae5-8217cb341ff8
# Sent 1a71f61c-8323-56f8-93b1-8f90135617d1
# Sent 75d3db48-c748-5be4-bf5b-c13db430c0f2
# Sent fb89429b-f929-5e65-af9a-1ef0d8a16c68
# Sent b6f19a93-ae89-5564-9246-6b9428bfffb1
# Sent 3db8013f-f577-5293-8b1e-49d90e674ba6
# Sent aacabd64-700c-55a0-97f9-c853542b6754
# Sent eac53488-20c0-50cf-90e6-7a71924c9f7b
# Sent 1fa4a78d-25d9-5ccf-8566-031aafcf19a2
# Sent 75996454-a7ab-5d0e-ab9e-db0075f69ae0
# Sent 885f8012-fec0-5f4e-9b1f-c58ceb4bd882
# Sent 79388ac9-3256-5641-80e7-260ecd98a079
# Sent 5a61a66f-4500-5710-a817-074f355e6506
# Sent 47551a2c-236f-5666-a611-a93589ead1fd
# Sent 0ade447f-dea0-5ad7-a2d0-54c7d0b758fe
# Sent 07f69a99-25c2-5642-a3d3-708496022d13
# Sent 7e36f291-1030-5fa8-bd0d-b22959da23df
# Sent 37a8e008-562a-5166-a90f-a6f77fc3f841
# Sent 1f9be24c-ab70-554c-8493-03201e663259
# Sent 483c5cfa-0bd9-583b-a78d-a809f7767791
# Sent 0e1827b6-c0a8-5c4f-87fb-fbc9fa519f6d
# Sent c2d9aa45-bdb7-5de4-a442-7a642b7e5b78
# Sent e5eed8b9-116f-55e9-b462-00dd16f329c0
# Sent 8a1a4fa0-17b0-5950-8423-82879d645ba6
# Sent 98c95f0d-3301-5781-b78e-16a1683aa541
# Sent 6f6fe82a-fe28-5e30-9985-18b79987fa3e
# Sent 83cd186f-1640-5c29-800f-091d484bcc79
# Sent 7d0ac939-a8e1-58ef-8a9a-5acb73ea07fb
# Sent 32c461fe-9a1d-5c39-86d1-2fb046197c33
# Sent b8ad163e-ad4b-5cdc-9506-0a38527b2d9d
# Sent 84041a50-79e2-5f5f-b134-28fa427e82ee
# Sent f946e907-0f0a-51b3-a8ad-6418692845e2
# Sent f560c8a8-4fc0-5815-9461-526bdef293eb
# Sent 05e0393c-5506-58a5-9a54-76925aa772e0
# Sent d798fff9-926c-5c5f-a057-a514010e21f7
# Sent c498ed02-45bc-59f4-a443-4e7d4c80b372
# Sent 89581da6-c3f2-509a-bb5f-e567b380bb72
# Sent 0475fcdb-53bf-5589-8f2c-cddb4772e584
# Sent 28041afd-bbd6-542f-a270-a65244153ad2
# Sent 89dba2a2-c932-5a76-81f7-6f6631bb0574
# Sent 224fe4d2-afe9-5c09-8c6f-4dbf53d4a7b0
# Sent 553d0d41-afa4-5cf9-8b4e-abfc48f50e49
# Sent 9988b526-c622-54b7-9f4a-90db1cb7807e
# Sent 67ea54ed-41ac-5433-bfa7-14bd42ff3857
# Sent 15f4dd83-091e-5d4b-9877-804dcc820019
# Sent 944fbf58-ff59-507f-b156-b60ebb85fc8b
# Sent a5192fd6-29d2-5f17-836f-8986fad6d149
# Sent 232cbb91-d089-5cde-8dd7-a48dfc14aec8
# Sent 7c661237-75c2-58c5-8449-fd31075c0a5e
# Sent d164efde-b416-5a9a-88f9-2e2bf960d479
# Sent 82b23ff3-4d52-5d76-8c86-97bccb17484d
# Sent 2f3306a7-c18f-5691-a187-06b48fa0f6d3
# Sent a7a0a575-ad7a-51f1-8381-b193b0a4124e
# Sent 91166208-6a81-5f4f-8658-70b603115365
# Sent fe175dc8-7dd5-5dd0-96be-24327dc2458c
# Sent 77196c0d-37ff-547b-8636-824dc41e0b19
# Sent 85a777ca-01c9-512c-963f-c9605c78ac71
# Sent 927aef77-92e8-5c3a-ad4d-adaa265eeb35
# Sent 0c49ab70-0511-5f76-b286-196d16c9c29e
# Sent 37f4a046-19ec-5361-88ed-8e5b2743cc6b
# Sent 154d6c63-e8e3-54eb-9554-f160517472e6
# Sent 0a47d794-3b03-55d2-bb55-e844624df16c
# Sent 920de085-cbc5-5fed-a4f1-b053f7c37e18
# Sent 2ad7370e-7399-540d-bf2f-b60a61393851
# Sent d3fee912-828d-5537-b734-bce22873bcaa
# DONE! check csvOutput/output_27-11-2021.csv
